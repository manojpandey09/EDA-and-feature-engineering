# %% [markdown]
# ### EDA

# %% [markdown]
# # 📊 Ultimate Master Table: EDA (Exploratory Data Analysis) – Deep Dive
#
# | 🔢 Step | 📌 Kya Check Karna Hai?                            | ✅ Kya Karna Hai / Logic                                                                                       | 🧮 Formula / Code Example                                              | 🧪 Output / Explanation                              |
# |--------|---------------------------------------------------|----------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------|------------------------------------------------------|
# | 1️⃣     | Data ka structure kya hai?                         | Rows, columns, datatypes, size check karo                                                                      | `df.shape`, `df.dtypes`, `df.info()`                                  | Dataset overview milta hai                        |
# | 2️⃣     | Pehle kuch rows dekhni hai?                        | Top, bottom & random sample row check karo                                                                     | `df.head()`, `df.tail()`, `df.sample(5)`                              | Data kaisa dikhta hai, samajh aata hai            |
# | 3️⃣     | Kya missing values hain?                           | Missing count aur % check karo                                                                                 | `df.isnull().sum()` <br> `(df.isnull().sum() / len(df)) * 100`         | Null value handle karne ke liye planning hoti hai |
# | 4️⃣     | Descriptive stats chahiye?                         | Numerical & categorical columns ka summary nikalo                                                              | `df.describe()`, `df.describe(include='object')`                      | Mean, std dev, min, max milta hai                 |
# | 5️⃣     | Column types segregate karne hain?                 | Numerical & Categorical alag karo                                                                              | `df.select_dtypes(include='number')` <br> `include='object'`           | Analysis simplify hota hai                       |
# | 6️⃣     | Univariate analysis karni hai (1 column)?          | Numerical: hist, boxplot, skew <br> Categorical: value_counts, countplot                                       | `df['col'].hist()`, `sns.boxplot(x=df['col'])`, `df['col'].skew()`     | Distribution samajh aata hai                      |
# | 7️⃣     | Outliers detect karne hain?                        | Boxplot, IQR method, Z-score use karo                                                                          | **IQR**: Q1, Q3 → `Q3 - Q1` <br> **Z-score**: `zscore(df['col'])`      | Outlier handle karne me help karta hai            |
# | 8️⃣     | Do column ka relation samajhna hai?                | Numerical vs Numerical: scatter, corr <br> Cat vs Num: boxplot <br> Cat vs Cat: crosstab                       | `sns.scatterplot()`, `sns.heatmap()`, `pd.crosstab()`                  | Feature relationships milte hain                  |
# | 9️⃣     | Duplicate rows hain kya?                           | Duplicate count nikalo                                                                                         | `df.duplicated().sum()`                                               | Data cleaning me use hota hai                     |
# | 🔟     | Target column balanced hai kya?                    | Classification problems ke liye check karo                                                                     | `df['target'].value_counts(normalize=True)`                           | Imbalance detect hota hai                         |
# | 1️⃣1️⃣  | Multicollinearity detect karni hai?                | Highly correlated features drop karo                                                                          | `sns.heatmap(df.corr())` <br> `drop columns with corr > 0.85`          | Redundant columns remove hote hain                |
# | 1️⃣2️⃣  | Full EDA flow samajhna hai?                        | Step-wise flow follow karo                                                                                     | Summary below                                                         | Full process visualize hota hai                  |
#
# ---
#
#  ✅ Full EDA Flow (Recap):
#
# 1. Data shape and types check
# 2. View head/tail/sample
# 3. Missing values
# 4. Descriptive statistics
# 5. Data type segregation
# 6. Univariate analysis
# 7. Outlier detection
# 8. Bivariate analysis
# 9. Duplicates check
# 10. Target imbalance
# 11. Correlation analysis
#
# ---

# %% [markdown]
# # 🧠 EDA Self-Questions – Think Like a Data Scientist
#
# ## ✅ 1. How big is the data?
# df.shape
#
# ## ✅ 2. What are the column names?
# df.columns
#
# ## ✅ 3. What are the data types of each column?
# df.dtypes
#
# ## ✅ 4. Are there any missing values (NaN)?
# df.isnull().sum()
#
# ## ✅ 5. What is the total number of missing values?
# df.isnull().sum().sum()
#
# ## ✅ 6. What are the summary statistics for numerical columns?
# df.describe()
#
# ## ✅ 7. What is the memory usage of the data?
# df.info()
# df.info(deep=True)  # Accurate memory usage including strings/objects
#
# ## ✅ 8. Are there any duplicate rows?
# df.duplicated().sum()
#
# ## ✅ 9. What are the unique values in a column?
# df['column_name'].unique()
#
# ## ✅ 10. How many unique values are there?
# df['column_name'].nunique()
#
# ## ✅ 11. How is the data distributed (categorical)?
# df['column_name'].value_counts()
#
# ## ✅ 12. What is the correlation between numeric features?
# df.corr()
#
# ## ✅ 13. Are there outliers in the data?
# import seaborn as sns
# sns.boxplot(data=df['column_name'])
#
# ## ✅ 14. What is the trend of the target variable?
# sns.countplot(x='target_column', data=df)
#
# ## ✅ 15. Are all columns useful (nulls, variance, redundancy)?
# # Drop columns with high missing %, low variance, or duplicate info if needed
#
# ## ✅ 16. Are there relationships between columns?
# sns.pairplot(df)
# sns.scatterplot(x='col1', y='col2', data=df)
#
# ## ✅ 17. What is the time range of the data (if date present)?
# df['date'].min(), df['date'].max()
#
# ## ✅ 18. Any imbalance in categorical classes?
# df['category_column'].value_counts(normalize=True)
#
# ## ✅ 19. How many nulls per row?
# df.isnull().sum(axis=1)
#
# ## ✅ 20. Are data types optimized (convert if needed)?
# df.dtypes
# # Use df.astype() if needed
#
# ---
#
# ## 🧪 Bonus Thinking: Ask Like a Data Scientist
# - What problem am I solving?
# - Which features are most relevant?
# - Is the target variable categorical or continuous?
# - Is the dataset clean and balanced?

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv("titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ###### Question ask ur self
# - How big the data is = size of the data  // df.shape()

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.memory_usage(deep = True)
# Out:
# Index            132
# PassengerId     7128
# Survived        7128
# Pclass          7128
# Name           67685
# Sex            47851
# Age             7128
# SibSp           7128
# Parch           7128
# Ticket         49674
# Fare            7128
# Cabin          32712
# Embarked       44514
# dtype: int64

# %% [markdown]
# #### Q = how the data look like / df.head()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 782          783         0       1
# 117          118         0       2
# 752          753         0       3
# 18            19         0       3
# 177          178         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 782                             Long, Mr. Milton Clyde    male  29.0      0
# 117                    Turpin, Mr. William John Robert    male  29.0      1
# 752                   Vande Velde, Mr. Johannes Joseph    male  33.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 177                         Isham, Miss. Ann Elizabeth  female  50.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 782      0    113501  30.0000    D6        S
# 117      0     11668  21.0000   NaN        S
# 752      0    345780   9.5000   NaN        S
# 18       0    345763  18.0000   NaN        S
# 177      0  PC 17595  28.7125   C49        C

# %% [markdown]
# ##### Q - what are the data types of column ?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #####  how my data look like mathmaticALLY annalysis

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(). T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# #### Q -CHECK missing values

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# #### check the dubplicate value

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ##### check the unique value

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# #### correction between coloumns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.select_dtypes(include='number').corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
h = df.select_dtypes(include='number').corr()

# %%
## heatmap

# %%
sns.heatmap(h)
# Out:
# <Axes: >

# %%
sns.heatmap(h , annot = True)  #annot = true give the value
# Out:
# <Axes: >

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) – Step-by-Step Ordered Breakdown
#
# EDA ka main goal hai data ko samajhna, clean karna, aur model ke liye ready karna.
# Neeche diya gaya hai **ordered structure of EDA**:
#
# ---
#
# ## 1️⃣ **Data Types & Structure Check**
#
# | 🔍 **What**              | Check data type, structure, size              |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `df.info()`, `df.dtypes`, `df.shape`, `df.columns` |
# | 🎯 **Purpose**            | Pehle samjho ki kaunse columns numeric, categorical, ya datetime hain. Data size kitna bada hai. |
#
# ---
#
# ## 2️⃣ **Missing Value Analysis**
#
# | 🔍 **What**              | Find missing/null values                      |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `df.isnull().sum()`, `sns.heatmap()`          |
# | 🎯 **Purpose**            | Samjho kitne columns me missing data hai, unka % kya hai, aur kya drop/impute karna hai. |
#
# ---
#
# ## 3️⃣ **Univariate Analysis (One Column)**
#
# | 🔍 **What**              | Analyze one feature at a time                 |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `histplot`, `countplot`, `boxplot`, `describe()` |
# | 🎯 **Purpose**            | Column ka distribution, central tendency (mean/median), frequency ya outlier detect karna. |
#
# ---
#
# ## 4️⃣ **Outlier Detection**
#
# | 🔍 **What**              | Find extreme or unusual values                |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `boxplot`, IQR method, Z-score                |
# | 🎯 **Purpose**            | Outliers modeling ko bigaad sakte hain. Visual ya mathematical methods se pakadna hota hai. |
#
# ---
#
# ## 5️⃣ **Bivariate Analysis (Two Columns)**
#
# | 🔍 **What**              | Relationship between two variables            |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `scatterplot`, `boxplot(x, y)`, `barplot`, `crosstab` |
# | 🎯 **Purpose**            | Ek feature ka dusre ke sath kya relation hai (correlation, comparison, class balance) |
#
# ---
#
# ## 6️⃣ **Multivariate Analysis (3+ Columns)**
#
# | 🔍 **What**              | Multiple features ka combined effect          |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `pairplot`, `catplot`, `FacetGrid`, `hue`     |
# | 🎯 **Purpose**            | Complex patterns aur clusters identify karna using more than 2 variables. |
#
# ---
#
# ## 7️⃣ **Correlation Analysis**
#
# | 🔍 **What**              | Numerical features ke beech ka correlation     |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `df.corr()`, `sns.heatmap(annot=True)`        |
# | 🎯 **Purpose**            | Linear relationships aur feature selection ke liye important hai. |
#
# ---
#
# ## 8️⃣ **Target Variable Analysis**
#
# | 🔍 **What**              | Target column ke sath relation analysis       |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `countplot`, `violinplot`, `boxplot`, groupby |
# | 🎯 **Purpose**            | Target ke imbalance ko check karna, aur features ka us par kya effect hai ye dekhna. |
#
# ---
#
# ## 9️⃣ **Time Series / Date-Based Analysis (If applicable)**
#
# | 🔍 **What**              | Date/time data ke trend analyze karna         |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | `lineplot`, `plot(x='date', y='value')`       |
# | 🎯 **Purpose**            | Seasonal trend, growth, decline ya pattern detect karna. |
#
# ---
#
# ## 🔟 **Final Visualization Summary**
#
# | 🔍 **What**              | All important plots for story-telling         |
# |--------------------------|-----------------------------------------------|
# | 🛠️ Tools/Methods         | - Heatmaps<br>- Pairplots<br>- Countplots<br>- Boxplots<br>- Scatterplots |
# | 🎯 **Purpose**            | Data ko clearly dikhana for insights and stakeholder presentations. |
#
# ---
#
# ## 📌 Bonus: Use These Plots As Per Situation
#
# | 🧪 Analysis Type       | 📈 Plot Types                                             |
# |------------------------|-----------------------------------------------------------|
# | Univariate (1 col)     | `histplot`, `countplot`, `boxplot`, `kdeplot`            |
# | Bivariate (2 cols)     | `scatterplot`, `boxplot`, `barplot`, `lineplot`          |
# | Multivariate (3+ cols) | `pairplot`, `catplot`, `FacetGrid`, `hue-based` plots     |
# | Correlation            | `heatmap` with `annot=True`                              |
# | Time series            | `lineplot`, `.plot(x='date', y='value')`                 |
#
# ---
#
# 💡 **Interview Tip**:
# > "EDA is not just about code — it's about asking the right questions:
# > - What does this feature tell me?
# > - Is it useful for prediction?
# > - Is there bias, outlier, or pattern I should worry about?"

# %% [markdown]
# ## univerate analaysis
# ## biverate analysis
# ## multivariate analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 1 univerate ( 1 column)
#
# ### varaible
# - cateogircal variable
# - numerical varaible
#
#
# =   segriciate the categorical and numerical

# %%
# method1 


cat = [column for column in df.columns if df[column].dtype =='object']
cat
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
#method 2

df.columns[df.dtypes == 'object']
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#methd2


df.columns[df.dtypes != 'object']
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#method1 


num = [column for column in df.columns if df[column].dtype != 'object']
num
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df[cat]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[num]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %% [markdown]
# ## 1 -  categorical column
# - 1 = Count plot
# - 2 = pie chart
# - 3 = numerical column

# %% [markdown]
# #### count plot

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a = df['Embarked']
a
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
a.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# #### Pie chart

# %%
df['Sex'].value_counts().plot(kind = 'pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2 - numerical column

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.hist(df["Age"], bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ###### Distplot

# %%
sns.distplot(df['Age'] )
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2072\3603442855.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'] )
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'], orient = 'h')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
 df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
1 - 0.38910778230082704
# Out:
# 0.6108922176991729

# %% [markdown]
# # Biverate analysis (2 coloumns )
# -Bivariate analysis is the statistical analysis of exactly two variables to understand the relationship, association, or correlation between them.

# %% [markdown]
# | 🧩 Variable 1 (X) | 🧩 Variable 2 (Y)   | 🧠 Type of Analysis        | 📊 Chart Type                | 🛠️ Function / Code Example                                         | 📦 Library           |
# | ----------------- | ------------------- | -------------------------- | ---------------------------- | ------------------------------------------------------------------- | -------------------- |
# | **Categorical**   | **Categorical**     | Frequency/Association      | Grouped Bar Chart, Heatmap   | `pd.crosstab(df['X'], df['Y']).plot(kind='bar')`<br>`sns.heatmap()` | Pandas / Seaborn     |
# | **Categorical**   | **Numerical**       | Distribution by Category   | Box Plot, Violin Plot        | `sns.boxplot(x='X', y='Y', data=df)`<br>`sns.violinplot()`          | Seaborn              |
# | **Numerical**     | **Categorical**     | Same as above (just order) | Box Plot, Violin Plot        | `sns.boxplot(x='Y', y='X', data=df)`                                | Seaborn              |
# | **Numerical**     | **Numerical**       | Correlation/Trend          | Scatter Plot, Line Plot      | `sns.scatterplot(x='X', y='Y', data=df)`<br>`sns.lineplot()`        | Seaborn / Matplotlib |
# | **Numerical**     | **Numerical**       | Correlation Measurement    | Heatmap (Correlation Matrix) | `df.corr()`<br>`sns.heatmap(df.corr(), annot=True)`                 | Pandas / Seaborn     |
# | **Categorical**   | **Target Variable** | Classification Trends      | Bar, Countplot, Cross-tab    | `sns.countplot(x='X', hue='target', data=df)`                       | Seaborn              |

# %%
iris = pd.read_csv("iris.csv")
tips = pd.read_csv("tipsEDA.csv")
flights = pd.read_csv("flights.csv")

# %% [markdown]
# ### scatter plot ,
# ## when x = num , y = num

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###### both x and y catorgical

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## x = catogorical , y = numerical
# # bar  plot

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x='Pclass', y='Age', data=df , hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ###### x = catogorical , y = numerical
# #### box plot

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(x='Sex', y='Age', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x='Sex', y='Age', data=df , hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[['Survived']]==0
# Out:
#      Survived
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
# ..        ...
# 886      True
# 887     False
# 888      True
# 889     False
# 890      True
#
# [891 rows x 1 columns]

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Survived']==0]['Age']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
##zero means didnt survive and 1 means survive  

df[df['Survived']==0]['Age'].max()
# Out:
# 74.0

# %%
df[df['Survived']==0]['Age'].min()
# Out:
# 1.0

# %%
##1 means survive 


df[df['Survived']==1]['Age'].max()
# Out:
# 80.0

# %%
df[df['Survived']==1]['Age'].min()
# Out:
# 0.42

# %%
sns.distplot(df[df['Survived']==0]['Age'] , hist = False)
sns.distplot(df[df['Survived']==1]['Age'] , hist = False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2072\2631502938.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'] , hist = False)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2072\2631502938.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## x= catgo , y = catgo

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
pd.crosstab(df['Pclass'] , df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'] , df['Survived']), annot = True)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris , hue = 'species')

# %%
sns.lineplot(x = "total_bill", y = "tip" , data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip" , data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flights.he
# Out:
#   AvgTicketPrice  Cancelled  \
# 0       $668.22       False
# 1       $519.25       False
# 2       $847.82       False
# 3       $572.58       False
# 4     $1,146.29       False
#
#                                                 Dest DestAirportID  \
# 0                San Francisco International Airport           SFO
# 1                        Tulsa International Airport           TUL
# 2  Winnipeg / James Armstrong Richardson Internat...           YWG
# 3               Xi'an Xianyang International Airport           XIY
# 4                     Malpensa International Airport          MI12
#
#     DestCityName DestCountry  \
# 0  San Francisco          US
# 1          Tulsa          US
# 2       Winnipeg          CA
# 3          Xi'an          CN
# 4          Milan          IT
#
#                                         DestLocation DestRegion DestWeather  \
# 0  {\n  "lat": "37.61899948",\n  "lon": "-122.375...      US-CA       Sunny
# ...

# %%
flights.head(1)
# Out:
#   AvgTicketPrice  Cancelled                                 Dest  \
# 0       $668.22       False  San Francisco International Airport
#
#   DestAirportID   DestCityName DestCountry  \
# 0           SFO  San Francisco          US
#
#                                         DestLocation DestRegion DestWeather  \
# 0  {\n  "lat": "37.61899948",\n  "lon": "-122.375...      US-CA       Sunny
#
#   DistanceKilometers  ... FlightTimeMin                        Origin  \
# 0          10,260.84  ...       488.611  Naples International Airport
#
#    OriginAirportID OriginCityName OriginCountry  \
# 0             NA01         Naples            IT
#
#                                     OriginLocation OriginRegion OriginWeather  \
# 0  {\n  "lat": "40.886002",\n  "lon": "14.2908"\n}        IT-72         Sunny
#
#   dayOfWeek hour_of_day
# 0         5          16
#
# [1 rows x 26 columns]

# %%
flights
# Out:
#     AvgTicketPrice  Cancelled  \
# 0         $668.22       False
# 1         $519.25       False
# 2         $847.82       False
# 3         $572.58       False
# 4       $1,146.29       False
# ..             ...        ...
# 319       $341.56       False
# 320       $563.14       False
# 321       $847.74       False
# 322       $801.88        True
# 323       $753.72       False
#
#                                                   Dest DestAirportID  \
# 0                  San Francisco International Airport           SFO
# 1                          Tulsa International Airport           TUL
# 2    Winnipeg / James Armstrong Richardson Internat...           YWG
# 3                 Xi'an Xianyang International Airport           XIY
# 4                       Malpensa International Airport          MI12
# ..                                                 ...           ...
# 319                                New Chitose Airport           CTS
# ...

# %% [markdown]
# # Multivarient Analysis (3 columns )

# %% [markdown]
# | 🧩 Variable 1 (X)    | 🧩 Variable 2 (Y) | 🧩 Variable 3 / More      | 🧠 Type of Analysis               | 📊 Chart Type                       | 🛠️ Function / Code Example                                                                     | 📦 Library   |
# | -------------------- | ----------------- | ------------------------- | --------------------------------- | ----------------------------------- | ----------------------------------------------------------------------------------------------- | ------------ |
# | Numerical            | Numerical         | Categorical (hue)         | 3-variable interaction            | Scatter Plot with hue               | `sns.scatterplot(x='X', y='Y', hue='Z', data=df)`                                               | Seaborn      |
# | Numerical            | Numerical         | Categorical (hue & style) | Grouped scatter analysis          | Scatter Plot with hue + style       | `sns.scatterplot(x='X', y='Y', hue='A', style='B', data=df)`                                    | Seaborn      |
# | Numerical            | Numerical         | Categorical (size)        | 4D visualization                  | Bubble Plot                         | `sns.scatterplot(x='X', y='Y', size='Z', hue='A', data=df)`                                     | Seaborn      |
# | Multiple Categorical | Numerical         | Categorical               | Category-wise distribution        | FacetGrid                           | `g = sns.FacetGrid(df, col='X', row='Y'); g.map(sns.scatterplot, 'A', 'B')`                     | Seaborn      |
# | Multiple Numerical   | —                 | —                         | Variable relationship overview    | Pair Plot                           | `sns.pairplot(df, hue='target')`                                                                | Seaborn      |
# | Numerical            | Numerical         | —                         | Correlation Matrix                | Heatmap (Correlation)               | `sns.heatmap(df.corr(), annot=True, cmap='coolwarm')`                                           | Seaborn      |
# | Mixed (Num + Cat)    | —                 | —                         | Data Reduction / Trend Extraction | PCA Plot / Dimensionality Reduction | `from sklearn.decomposition import PCA`<br>`pca = PCA(n_components=2)`<br>`pca.fit_transform()` | scikit-learn |
# | Categorical          | Categorical       | Target                    | Classification Analysis           | Grouped Countplot                   | `sns.countplot(x='X', hue='target', data=df)`                                                   | Seaborn      |

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# both x 

sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips , style = tips["smoker"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex' , data=tips , size = tips["size"] , style = tips["smoker"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
from pandas_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2072\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
ProfileReport(iris)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-07-09 10:12:26.540864&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
